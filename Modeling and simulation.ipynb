# %%
#Solving and modeling prey-hunter diff equation varying some parameters

import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
import math  as mt
from scipy.integrate import solve_ivp
from pylab import *

def exponential_decay(t,N, alpha, beta, A, a):
    dNdt = N*(a-(beta*N**(1-alpha))/A)
    return (dNdt)

a=1
A=2
alpha=0.5
beta=0.4

sol = solve_ivp(exponential_decay, [0, 100], [20],args=[alpha, beta, A, a],dense_output=True)
sol1 = solve_ivp(exponential_decay, [0, 100], [30],args=[alpha, beta, A, a],dense_output=True)

t = np.linspace(0, 100, 1001)
v = sol.sol(t)
z = sol1.sol(t)
print(t,v)

xmax = 100
xmin = 0

ymax = 30
ymin = 20

Nx=10
Ny=10

x=np.linspace(xmin, xmax, Nx)
y=np.linspace(ymin, ymax, Nx)

X, Y= np.meshgrid(x, y)

Bx= 1
By= Y*(a-(beta*Y**(1-alpha))/A)

figure(figsize=[7,7])

QP = quiver(X, Y, Bx, By,linewidth=0.2, color= 'r' )

plt.plot(t,v[0])
plt.plot(t,z[0])

plt.show()
# Out:
# [  0.    0.1   0.2 ...  99.8  99.9 100. ] [[20.         20.2075555  20.40800143 ... 24.99632064 24.99648486
#   24.99665076]]

# %%
def logistical_equation(t,z, alpha1, alpha2, y1, y2):
    r,f = z
    drdt = y1*r-alpha1*r*f
    dfdt = -y2*f+alpha2*r*f
    return (drdt, dfdt)

#r=rabbits
#f=foxs
alpha1=0.01
alpha2=0.01
y1=2
y2=1

sol = solve_ivp(logistical_equation, [0, 100], [100, 5],args=[alpha1, alpha2, y1, y2],dense_output=True)
t = np.linspace(0, 100, 1001)
z = sol.sol(t)


ax = plt.figure().add_subplot(projection='3d')

ax.plot(z[0], t, z[1], lw=0.5)
ax.set_xlabel("rabbits")
ax.set_ylabel("time")
ax.set_zlabel("foxs")
ax.set_title("3d model (foxs vs rabbits vs time)")

plt.show()

# %%
ay= plt.figure().add_subplot()

ay.plot(z[0], z[1], lw=0.5)
ay.set_xlabel("rabbits")
ay.set_ylabel("foxs")
ay.set_title("rabbits vs foxs")

plt.show()

# %%
ay= plt.figure().add_subplot()
t2=np.linspace(0, 10, 1001)

ay.plot(t2, z[0], lw=0.5)
ay.set_xlabel("time")
ay.set_ylabel("rabbits")
ay.set_title("rabbits vs time")

plt.show()

# %%
ay= plt.figure().add_subplot()

ay.plot(t, z[1], lw=0.5)
ay.set_xlabel("time")
ay.set_ylabel("foxs")
ay.set_title("foxs vs time")

plt.show()

# %%
ay= plt.figure().add_subplot()

ay.plot(z[0], z[1], lw=0.5)
ay.set_xlabel("rabbits")
ay.set_ylabel("foxs")
ay.set_title("foxs vs rabbits")

plt.show()

# %%
def logistical_equation(t,z, alpha1, alpha2, y1, y2):
    r,f = z
    drdt = y1*r-alpha1*r*f
    dfdt = -y2*f+alpha2*r*f
    return (drdt, dfdt)

#r=conejos
#f=zorros
alpha1=1
alpha2=1
y1=2
y2=1

sol = solve_ivp(logistical_equation, [0, 100], [100, 5],args=[alpha1, alpha2, y1, y2],dense_output=True)
t = np.linspace(0, 100, 1001)
z = sol.sol(t)

#fig, ax = plt.subplots()

# %%
ay= plt.figure().add_subplot()

ay.plot(t, z[1], lw=0.5)
ay.set_xlabel("time")
ay.set_ylabel("foxs")
ay.set_title("foxs vs time")

plt.show()

# %%
ax = plt.figure().add_subplot(projection='3d')

ax.plot(z[0], t, z[1], lw=0.5)
ax.set_xlabel("rabbits")
ax.set_ylabel("time")
ax.set_zlabel("foxs")
ax.set_title("3d model (foxs vs rabbits vs time)")

plt.show()

# %%
ay= plt.figure().add_subplot()
t2=np.linspace(0, 10, 1001)

ay.plot(t2, z[0], lw=0.5)
ay.set_xlabel("time")
ay.set_ylabel("rabbits")
ay.set_title("rabbits vs time")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def lorenz(x, y, z, s=10, r=28, b=2.667):
    """
    Given:
       x, y, z: a point of interest in three dimensional space
       s, r, b: parameters defining the lorenz attractor
    Returns:
       x_dot, y_dot, z_dot: values of the lorenz attractor's partial
           derivatives at the point x, y, z
    """
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return x_dot, y_dot, z_dot


dt = 0.01
num_steps = 10000

# Need one more for the initial values
xs = np.empty(num_steps + 1)
ys = np.empty(num_steps + 1)
zs = np.empty(num_steps + 1)

# Set initial values
xs[0], ys[0], zs[0] = (0., 1., 1.05)

# Step through "time", calculating the partial derivatives at the current point
# and using them to estimate the next point
for i in range(num_steps):
    x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
    xs[i + 1] = xs[i] + (x_dot * dt)
    ys[i + 1] = ys[i] + (y_dot * dt)
    zs[i + 1] = zs[i] + (z_dot * dt)


# Plot
ax = plt.figure().add_subplot(projection='3d')

ax.plot(xs, ys, zs, lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %%
# Plot
ax = plt.figure().add_subplot(projection='3d')
t=np.linspace(0, 10001, 10001)
ax.plot(t, xs, ys, lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %%
#modeling logistic regression equation
import numpy as np
import matplotlib.pyplot as plt
from random import randint
import pandas as pd

def logistic_iteration(N, xinicial, r):
    logistic=0
    for i in range(N):
        logistic = r*xinicial*(1-xinicial)
        xinicial = logistic
        return logistic

valor_f = []
eje_r = []
valor_r = list(np.linspace(0, 4 , 100000))

N = 2000
Xo = 0.5
for elems in valor_r:
    log = 0
    log = logistic_iteration(randint(100, N), Xo, elems)
    valor_f.append(log)
    eje_r.append(elems)

plt.scatter(eje_r, valor_f)
plt.show()

# %%
#Modeling exponencial decay equation
ti=0; tf=100; dt=0.1
N=5
tspam=[ti, tf]
a=1
A=2
alpha=1
beta=1
def exponential_decay(t,N, alpha, beta, A, a):
    dNdt = N*(a-(beta*N**(1-alpha))/A)
    return (dNdt)

for x0 in np.arange(0,100,0.2):
    sol = solve_ivp(exponential_decay, tspam, [x0],args=[alpha, beta, A, a],dense_output=True)
    u=sol.sol(x0)
    plt.scatter(u, x0, color='darkgreen', marker='.')

tspam1=[ti, tf]

for x0 in np.arange(-100,0,0.2):
    sol = solve_ivp(exponential_decay, tspam1, [x0],args=[alpha, beta, A, a],dense_output=True)
    v=sol.sol(x0)
    plt.scatter(v, x0, color='red', marker='.')


plt.axis([-100, 100, -10, 10])
plt.grid()
